# %%
import pandas as pd
from pathlib import Path
import numpy as np

base_path = Path('../../..').parent.absolute()

yield_data = pd.read_parquet(f'{base_path}/Data/processed/africa_crop_yield_data.parquet')
yield_data.index = pd.to_datetime(yield_data.index, format='%Y').to_period('A')

# yield_data = yield_data.pct_change()
yield_data = yield_data.pct_change()
yield_data = yield_data.replace(0, 0.01)

# %%
climate_data = pd.read_parquet(f'{base_path}/Data/processed/climate_full.parquet')

climate_data.index = pd.date_range(start='1901-01-01', end='2100-12-31', freq='A').to_period('A')

climate_data = climate_data.loc[:'2021', :]

country_map = pd.read_csv('../../Data/resources/countries.csv', encoding="latin-1").set_index('alpha-3')

# Do some trickery to turn the columns into a MultiIndex.
climate_data.columns = pd.MultiIndex.from_tuples([[country_map.loc[x[0], 'name'], x[1], x[2], 'raw'] if len(x) == 3 else [country_map.loc[x[0], 'name'], x[1], x[2], x[3]] for x in climate_data.columns.str.split('_').to_list()])

# Convert the country ISO codes to country names.
climate_data = climate_data.groupby(level=[0,2,3], axis=1).first()

# %%
climate_data = climate_data.loc[:, climate_data.columns.get_level_values(1).isin(['prstar', 'tasstar', 'tas', 'pr'])]
climate_data.columns = climate_data.columns.droplevel(2)
climate_data
# Out:
#         Algeria                                                      Angola  \
#              pr          pr     prstar      tas    tas tasstar           pr
# 1901        NaN  102.860000        NaN      NaN  22.58     NaN          NaN
# 1902        NaN   91.500000        NaN      NaN  22.58     NaN          NaN
# 1903        NaN   73.280000        NaN      NaN  22.48     NaN          NaN
# 1904        NaN  105.600000        NaN      NaN  22.65     NaN          NaN
# 1905        NaN   87.810000        NaN      NaN  22.43     NaN          NaN
# ...         ...         ...        ...      ...    ...     ...          ...
# 2017  77.878000   68.880000  -8.998000  23.4000  23.60  0.2000   990.397600
# 2018  79.017200   88.240000   9.222800  23.4176  23.23 -0.1876   991.102400
# 2019  78.664800   70.910000  -7.754800  23.4264  23.38 -0.0464   994.069600
# 2020  77.826400   55.420000 -22.406400  23.4360  23.54  0.1040   998.447200
# 2021  76.490692   61.767304 -14.723388  23.4764  24.06  0.5836  1002.655788
#
#                                        ...      Zambia                  \
#                pr     prstar      tas  ...      prstar      tas    tas
# 1901   970.600000        NaN      NaN  ...         NaN      NaN  21.56
# 1902   988.090000        NaN      NaN  ...         NaN      NaN  21.81
# 1903  1013.010000        NaN      NaN  ...         NaN      NaN  21.88
# 1904   930.550000        NaN      NaN  ...         NaN      NaN  21.28
# 1905   929.880000        NaN      NaN  ...         NaN      NaN  21.77
# ...           ...        ...      ...  ...         ...      ...    ...
# 2017  1005.980000  15.582400  21.8528  ...  127.800400  22.2840  22.21
# 2018  1005.530000  14.427600  21.8556  ...   46.292400  22.2888  21.99
# 2019  1012.260000  18.190400  21.8608  ...   16.338000  22.2992  22.44
# 2020  1019.670000  21.222800  21.8508  ...   28.931200  22.2736  22.07
# 2021  1047.114699  44.458911  21.8668  ...   25.503297  22.2868  22.62
#
#                 Zimbabwe
#      tasstar          pr         pr      prstar      tas    tas tasstar
# 1901     NaN         NaN  836.85000         NaN      NaN  20.94     NaN
# 1902     NaN         NaN  655.70000         NaN      NaN  21.33     NaN
# 1903     NaN         NaN  549.50000         NaN      NaN  21.52     NaN
# 1904     NaN         NaN  694.97000         NaN      NaN  20.47     NaN
# 1905     NaN         NaN  508.35000         NaN      NaN  21.34     NaN
# ...      ...         ...        ...         ...      ...    ...     ...
# 2017 -0.0740  647.128400  863.07000  215.941600  21.7996  21.65 -0.1496
# 2018 -0.2988  644.506400  607.47000  -37.036400  21.8168  22.03  0.2132
# 2019  0.1408  653.722400  695.15000   41.427600  21.8552  22.30  0.4448
# 2020 -0.2036  661.696800  655.02000   -6.676800  21.8468  21.86  0.0132
# 2021  0.3332  658.820077  630.32193  -28.498147  21.8748  22.19  0.3152
#
# [121 rows x 312 columns]

# %%
full_df = climate_data.merge(yield_data, left_index=True, right_index=True).sort_index(axis=1)

df1 = full_df.melt(value_vars=full_df.columns.tolist(), var_name=['Country', 'Variable'],  ignore_index=False).reset_index()
df1['index'] = df1['index'].dt.to_timestamp()
full = df1.pivot_table(index=['Country', 'index'], columns='Variable', values='value')

# %%
full['tasstar2'] = full['tasstar'] ** 2
full['prstar2'] = full['prstar'] ** 2

full['tas2']= full['tas'] ** 2
full['pr2'] = full['pr'] ** 2

# %%
from linearmodels.panel import PanelOLS
import statsmodels.api as sm

out = pd.DataFrame()
res = {}

errored_vars = 0

for crop in full.columns[~full.columns.isin(['tas', 'tasstar', 'tasstar2', 'pr', 'prstar', 'prstar2', 't1', 'p1', 'tas2', 'pr2'])]:

    try:
        exog_vars = ['tasstar',  'tasstar2', 'prstar', 'prstar2']
        exog = full[exog_vars]

        model = PanelOLS(full[crop], exog, entity_effects=True)
        results = model.fit(cov_type='clustered', cluster_entity=True)

        out_cntry = results.estimated_effects
        res[crop] = results
        
        out_cntry[['tasstar', 'tasstar2', 'prstar', 'prstar2']] = results.params
        
        out_cntry['crop'] = crop
        out_cntry = out_cntry.reset_index().set_index(['Country', 'crop', 'index'])

        out = pd.concat([out, out_cntry], axis=0)
    
    except Exception as e:
        errored_vars += 1
        continue
# Out:
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# /Users/jackminchin/opt/anaconda3/lib/python3.8/site-packages/linearmodels/panel/model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)

# %%
major_crops = ['Wheat', 'Soybeans', 'Maize', 'Barley', 'Apples', 'Apricots', 'Beans, dry', 'Cabbages and other brassicas', 'Oats', 'Rice, paddy', 'Seed cotton', 'Tangerines, mandarins, clementines, satsumas', 'Tobacco, unmanufactured', 'Tomatoes', 'Watermelons']
regression_table = pd.DataFrame(index=major_crops, columns=exog_vars)

for crop in major_crops:
    results = res[crop]

    parameters = results.params
    pvalues = results.pvalues

    for i, param in parameters.iteritems():

        star = ''

        if pvalues[i] < 0.1:
            star = '*'
        elif pvalues[i] < 0.05:
            star = '**'
        elif pvalues[i] < 0.01:
            star = '***'


        regression_table.loc[crop, i] = f'{param:.4f}{star}'

regression_table.to_clipboard(index=True, header=True)
regression_table.columns = ['T', 'T$^2$', 'P', 'P$^2$' ]


regression_table.to_latex('../output/regression_table.tex', escape=False)

regression_table = regression_table.style.set_properties(**{'text-align': 'right'})



regression_table
# Out:
# /var/folders/z7/kscqgjb16xs6t1mmw0gy5p4m0000gn/T/ipykernel_58620/2220353973.py:28: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   regression_table.to_latex('../output/regression_table.tex', escape=False)
# <style type="text/css">
# #T_c3708_row0_col0, #T_c3708_row0_col1, #T_c3708_row0_col2, #T_c3708_row0_col3, #T_c3708_row1_col0, #T_c3708_row1_col1, #T_c3708_row1_col2, #T_c3708_row1_col3, #T_c3708_row2_col0, #T_c3708_row2_col1, #T_c3708_row2_col2, #T_c3708_row2_col3, #T_c3708_row3_col0, #T_c3708_row3_col1, #T_c3708_row3_col2, #T_c3708_row3_col3, #T_c3708_row4_col0, #T_c3708_row4_col1, #T_c3708_row4_col2, #T_c3708_row4_col3, #T_c3708_row5_col0, #T_c3708_row5_col1, #T_c3708_row5_col2, #T_c3708_row5_col3, #T_c3708_row6_col0, #T_c3708_row6_col1, #T_c3708_row6_col2, #T_c3708_row6_col3, #T_c3708_row7_col0, #T_c3708_row7_col1, #T_c3708_row7_col2, #T_c3708_row7_col3, #T_c3708_row8_col0, #T_c3708_row8_col1, #T_c3708_row8_col2, #T_c3708_row8_col3, #T_c3708_row9_col0, #T_c3708_row9_col1, #T_c3708_row9_col2, #T_c3708_row9_col3, #T_c3708_row10_col0, #T_c3708_row10_col1, #T_c3708_row10_col2, #T_c3708_row10_col3, #T_c3708_row11_col0, #T_c3708_row11_col1, #T_c3708_row11_col2, #T_c3708_row11_col3, #T_c3708_row12_col0, #T_c3708_row12_col1, #T_c3708_row12_col2, #T_c3708_row12_col3, #T_c3708_row13_col0, #T_c3708_row13_col1, #T_c3708_row13_col2, #T_c3708_row13_col3, #T_c3708_row14_col0, #T_c3708_row14_col1, #T_c3708_row14_col2, #T_c3708_row14_col3 {
#   text-align: right;
# }
# </style>
# <table id="T_c3708">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3708_level0_col0" class="col_heading level0 col0" >T</th>
#       <th id="T_c3708_level0_col1" class="col_heading level0 col1" >T$^2$</th>
#       <th id="T_c3708_level0_col2" class="col_heading level0 col2" >P</th>
#       <th id="T_c3708_level0_col3" class="col_heading level0 col3" >P$^2$ \footnote{T and P denote deviations from the long run trend of temperature and precipitation respectively, T$^2$ and P$^2$ are their squared terms.}</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3708_level0_row0" class="row_heading level0 row0" >Wheat</th>
#       <td id="T_c3708_row0_col0" class="data row0 col0" >-0.0166</td>
#       <td id="T_c3708_row0_col1" class="data row0 col1" >0.0243</td>
#       <td id="T_c3708_row0_col2" class="data row0 col2" >0.0002*</td>
#       <td id="T_c3708_row0_col3" class="data row0 col3" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row1" class="row_heading level0 row1" >Soybeans</th>
#       <td id="T_c3708_row1_col0" class="data row1 col0" >0.0040</td>
#       <td id="T_c3708_row1_col1" class="data row1 col1" >-0.0987*</td>
#       <td id="T_c3708_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_c3708_row1_col3" class="data row1 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row2" class="row_heading level0 row2" >Maize</th>
#       <td id="T_c3708_row2_col0" class="data row2 col0" >0.0347</td>
#       <td id="T_c3708_row2_col1" class="data row2 col1" >-0.1629*</td>
#       <td id="T_c3708_row2_col2" class="data row2 col2" >0.0002*</td>
#       <td id="T_c3708_row2_col3" class="data row2 col3" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row3" class="row_heading level0 row3" >Barley</th>
#       <td id="T_c3708_row3_col0" class="data row3 col0" >0.0188</td>
#       <td id="T_c3708_row3_col1" class="data row3 col1" >-0.0103</td>
#       <td id="T_c3708_row3_col2" class="data row3 col2" >0.0003*</td>
#       <td id="T_c3708_row3_col3" class="data row3 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row4" class="row_heading level0 row4" >Apples</th>
#       <td id="T_c3708_row4_col0" class="data row4 col0" >0.0233</td>
#       <td id="T_c3708_row4_col1" class="data row4 col1" >-0.0478*</td>
#       <td id="T_c3708_row4_col2" class="data row4 col2" >-0.0000</td>
#       <td id="T_c3708_row4_col3" class="data row4 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row5" class="row_heading level0 row5" >Apricots</th>
#       <td id="T_c3708_row5_col0" class="data row5 col0" >-0.0235*</td>
#       <td id="T_c3708_row5_col1" class="data row5 col1" >-0.0005</td>
#       <td id="T_c3708_row5_col2" class="data row5 col2" >-0.0001</td>
#       <td id="T_c3708_row5_col3" class="data row5 col3" >0.0000*</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row6" class="row_heading level0 row6" >Beans, dry</th>
#       <td id="T_c3708_row6_col0" class="data row6 col0" >0.0306</td>
#       <td id="T_c3708_row6_col1" class="data row6 col1" >-0.0509</td>
#       <td id="T_c3708_row6_col2" class="data row6 col2" >0.0001*</td>
#       <td id="T_c3708_row6_col3" class="data row6 col3" >-0.0000*</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row7" class="row_heading level0 row7" >Cabbages and other brassicas</th>
#       <td id="T_c3708_row7_col0" class="data row7 col0" >0.0045</td>
#       <td id="T_c3708_row7_col1" class="data row7 col1" >-0.0168</td>
#       <td id="T_c3708_row7_col2" class="data row7 col2" >-0.0000</td>
#       <td id="T_c3708_row7_col3" class="data row7 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row8" class="row_heading level0 row8" >Oats</th>
#       <td id="T_c3708_row8_col0" class="data row8 col0" >-0.0813</td>
#       <td id="T_c3708_row8_col1" class="data row8 col1" >0.0194</td>
#       <td id="T_c3708_row8_col2" class="data row8 col2" >0.0001</td>
#       <td id="T_c3708_row8_col3" class="data row8 col3" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row9" class="row_heading level0 row9" >Rice, paddy</th>
#       <td id="T_c3708_row9_col0" class="data row9 col0" >0.0167</td>
#       <td id="T_c3708_row9_col1" class="data row9 col1" >-0.0384</td>
#       <td id="T_c3708_row9_col2" class="data row9 col2" >-0.0000</td>
#       <td id="T_c3708_row9_col3" class="data row9 col3" >-0.0000*</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row10" class="row_heading level0 row10" >Seed cotton</th>
#       <td id="T_c3708_row10_col0" class="data row10 col0" >-0.0404</td>
#       <td id="T_c3708_row10_col1" class="data row10 col1" >-0.0429</td>
#       <td id="T_c3708_row10_col2" class="data row10 col2" >0.0001</td>
#       <td id="T_c3708_row10_col3" class="data row10 col3" >-0.0000*</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row11" class="row_heading level0 row11" >Tangerines, mandarins, clementines, satsumas</th>
#       <td id="T_c3708_row11_col0" class="data row11 col0" >-0.0148</td>
#       <td id="T_c3708_row11_col1" class="data row11 col1" >-0.0106</td>
#       <td id="T_c3708_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_c3708_row11_col3" class="data row11 col3" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row12" class="row_heading level0 row12" >Tobacco, unmanufactured</th>
#       <td id="T_c3708_row12_col0" class="data row12 col0" >-0.0242</td>
#       <td id="T_c3708_row12_col1" class="data row12 col1" >-0.0087</td>
#       <td id="T_c3708_row12_col2" class="data row12 col2" >-0.0000</td>
#       <td id="T_c3708_row12_col3" class="data row12 col3" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row13" class="row_heading level0 row13" >Tomatoes</th>
#       <td id="T_c3708_row13_col0" class="data row13 col0" >0.0041</td>
#       <td id="T_c3708_row13_col1" class="data row13 col1" >-0.0290*</td>
#       <td id="T_c3708_row13_col2" class="data row13 col2" >-0.0000</td>
#       <td id="T_c3708_row13_col3" class="data row13 col3" >-0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c3708_level0_row14" class="row_heading level0 row14" >Watermelons</th>
#       <td id="T_c3708_row14_col0" class="data row14 col0" >0.0214</td>
#       <td id="T_c3708_row14_col1" class="data row14 col1" >-0.0392</td>
#       <td id="T_c3708_row14_col2" class="data row14 col2" >0.0001</td>
#       <td id="T_c3708_row14_col3" class="data row14 col3" >-0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
out = out.sort_index().groupby(level=[0,1], axis=0).first()

# %%
out.to_parquet('./damage_coefficients.parquet')

# %%
# out = out[out['tas'] < 0]

# %%
out.to_parquet('./damage_coefficients.parquet')

# %%
out.to_excel('./damage_coefficients.xlsx')
